# %% [markdown]
# # Day 1 — A/B Testing Fundamentals
# **Week 4 | June 11**
#
# ## Paper of the Day
# 📄 [Controlled Experiments on the Web: Survey and Practical Guide — Kohavi et al. (2009)](https://www.researchgate.net/publication/220154032_Controlled_experiments_on_the_web_survey_and_practical_guide)
# The definitive A/B testing reference from Microsoft. Read sections 1–4 and 6 (pitfalls).
#
# ## Resources
# - [Evan Miller's sample size calculator — explained](https://www.evanmiller.org/ab-testing/sample-size.html)
# - [How Airbnb does A/B testing — blog](https://medium.com/airbnb-engineering/)
# - [Netflix experimentation platform — blog](https://netflixtechblog.com/its-all-a-bout-testing-the-netflix-experimentation-platform-4e1ca458c15b)
#
# ## Today's Goal
# Implement the full A/B test workflow: power analysis → randomization → measurement → decision.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# TODO: Implement power analysis from scratch
# Given: baseline_rate, min_detectable_effect, alpha, power
# Return: required sample size per arm
def compute_sample_size(baseline_rate: float, mde: float, alpha: float = 0.05, power: float = 0.80) -> int:
    pass

# Example: CTR = 1%, want to detect 10% lift (to 1.1%), alpha=0.05, power=0.8
# What sample size do you need?

# %%
# TODO: Implement two-proportion z-test from scratch
def z_test_two_proportions(n_control, clicks_control, n_treatment, clicks_treatment):
    # Returns (z_stat, p_value, reject_null)
    pass

# %%
# TODO: Simulate and visualize type I and type II errors
# Run 1000 simulated experiments where the null is TRUE (no effect)
# Count how many times you incorrectly reject null (type I error rate)
# Show it matches your alpha

# Then simulate with a real effect
# Count how many times you correctly detect it (power)

# %%
# TODO: Common pitfall — peeking
# Run an experiment and check the p-value every day
# Stop as soon as p < 0.05
# Show: false positive rate inflates to ~30% with daily peeking
# This is why you pre-commit to sample size

# %% [markdown]
# ## Reflection
# 1. What metrics would you use in an A/B test for a new CTR model at Pinterest? (hint: more than just CTR)
# 2. Experiment runs 7 days. Day 3 looks good, day 7 looks flat. Do you ship?
# 3. What's novelty effect, and why does it invalidate short experiments?
