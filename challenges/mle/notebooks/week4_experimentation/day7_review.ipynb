# %% [markdown]
# # Day 7 — Week 4 Review & Experiment Design Practice
# **Week 4 | June 17**
#
# ## No New Paper — Consolidation Day
#
# ## Full Experiment Design Exercise
# **Question (answer out loud for 15 minutes before writing):**
# > Pinterest is launching a new bidding algorithm that bids 15% more aggressively.
# > Design an experiment to measure its impact. Walk through every decision.
#
# ## Your Answer Should Cover:
# 1. **What experiment type?** User-level A/B, switchback, geo holdout — and why
# 2. **What metrics?** Primary + guardrail metrics, and why you chose them
# 3. **Sample size?** How did you compute it?
# 4. **How long to run?** Day-of-week effects, novelty effects
# 5. **What can go wrong?** Interference, peeking, selection bias
# 6. **Decision criteria?** When do you ship vs. rollback?

# %%
# TODO: Write your full experiment design as structured code/comments

experiment = {
    'hypothesis': '',
    'experiment_type': '',  # and why
    'primary_metric': '',
    'guardrail_metrics': [],
    'sample_size_per_arm': None,  # compute this
    'duration_days': None,  # and why
    'randomization_unit': '',  # user / session / time / geo
    'ship_criteria': '',
    'rollback_criteria': '',
    'known_risks': [],
}

# %%
# TODO: Compute sample size for your primary metric
# Use your compute_sample_size function from Day 1
# Baseline CTR: 1%, expected lift: 5% relative (to 1.05%), alpha=0.05, power=0.80

# %% [markdown]
# ## Week 4 Summary — Write From Memory
# Before looking at notes:
# 1. Why does user-level A/B fail in marketplace experiments?
# 2. How does CUPED reduce variance? What data does it require?
# 3. What is the Lagrange multiplier in the bidding problem?
# 4. Thompson Sampling: how do you update beliefs after a click?
# 5. What is lift/incrementality and why is naive measurement biased?
#
# ## Full Paper List — Week 4
# | Day | Paper |
# |-----|-------|
# | 1 | Kohavi et al. (2009) — Controlled Experiments on the Web |
# | 2 | Eckles et al. (2017) — Detecting Network Effects |
# | 3 | Deng et al. (2013) — CUPED |
# | 4 | Zhang et al. (2014) — Optimal Real-Time Bidding |
# | 5 | Li et al. (2010) — Contextual Bandit (LinUCB) |
# | 6 | Vaver & Koehler (2011) — Geo Experiments |
