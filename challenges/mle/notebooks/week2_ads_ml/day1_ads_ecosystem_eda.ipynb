# %% [markdown]
# # Day 1 — Ads Ecosystem & Criteo EDA
# **Week 2 | May 28**
#
# ## Paper of the Day
# 📄 [Ad Click Prediction: A View from the Trenches — McMahan et al., Google (2013)](https://dl.acm.org/doi/10.1145/2487575.2488200)
# The most important ads ML paper. Focus on: online learning (FTRL-Proximal), feature engineering, and system design. The ideas here are still used in production today.
#
# ## Resources
# - [RTB ecosystem diagram — IAB Tech Lab](https://iabtechlab.com/wp-content/uploads/2022/04/OpenRTB-API-Specification-Version-2_6-FINAL.pdf) (read pages 1-5 only)
# - [Programmatic advertising explained — Clearcode](https://clearcode.cc/blog/programmatic-advertising/)
# - [Pinterest's ads auction overview — Pinterest Engineering Blog](https://medium.com/pinterest-engineering)
#
# ## Ecosystem Cheat Sheet
# ```
# Advertiser → DSP → Ad Exchange → SSP → Publisher
#                        ↕
#                   Auction (RTB)
#                   Winner: highest eCPM
#                   eCPM = CTR × CVR × bid × 1000
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Criteo dataset
# df = pd.read_csv('path/to/train.csv', nrows=500000)
# Columns: Label, I1..I13 (numeric), C1..C26 (categorical/hashed)

# %%
# TODO: EDA — answer these questions with plots/code

# 1. What is the click rate? (class imbalance ratio)

# 2. For each numeric feature: distribution, % missing, correlation with label

# 3. For each categorical feature: cardinality, % missing, top-10 values

# 4. Feature I1 vs label: are higher values correlated with clicks?

# %%
# TODO: Simulate what raw data looks like in a real ads system
# Create a synthetic 'bid request' dataclass:
# - user_id, user_age_bucket, device_type, country
# - ad_id, advertiser_id, ad_format, bid_price
# - context: page_category, time_of_day, day_of_week
# - label: click
# Generate 1000 rows. This is what the feature pipeline processes.

# %% [markdown]
# ## Reflection
# 1. In a 2nd-price auction, you win but pay the 2nd-highest bid. Why does this incentivize truthful bidding?
# 2. What's bid shading and why is it needed in 1st-price auctions?
# 3. How does Pinterest fit into this stack — is it DSP, SSP, or exchange?
