# %% [markdown]
# # Day 5 — Evaluation Metrics From Scratch
# **Week 1 | May 25**
#
# ## Paper of the Day
# 📄 [The Relationship Between Precision-Recall and ROC Curves — Davis & Goadrich (2006)](https://dl.acm.org/doi/10.1145/1143844.1143874)
# Explains why PR-AUC is more informative than ROC-AUC for imbalanced datasets like CTR prediction.
#
# ## Resources
# - [Understanding AUC-ROC — Towards Data Science](https://towardsdatascience.com/understanding-auc-roc-curve-68b2303cc9c5)
# - [Log Loss explained — fast.ai](https://www.fast.ai/posts/2023-09-04-accuracy-vs-cross-entropy.html)
# - [Calibration curves — sklearn docs](https://scikit-learn.org/stable/auto_examples/calibration/plot_calibration_curve.html)
#
# ## Today's Goal
# Implement AUC, log-loss, and calibration curve from scratch. These are the three metrics you'll defend in every Pinterest ML interview.

# %%
import numpy as np
import matplotlib.pyplot as plt

# TODO: Implement AUC-ROC from scratch (trapezoidal rule)
# Do NOT use sklearn. Compute TPR/FPR at each threshold, then integrate.
def compute_auc_roc(y_true, y_score):
    pass

# TODO: Implement log-loss from scratch
def compute_log_loss(y_true, y_pred, eps=1e-7):
    pass

# TODO: Implement calibration curve
# Bin predictions into 10 buckets, compute mean predicted vs. mean actual per bucket
def calibration_curve(y_true, y_pred, n_bins=10):
    pass

# %%
# TODO: Demonstrate the key insight
# Create two models:
#   Model A: well-ranked but poorly calibrated (AUC=0.85, predicted probs all 2x too high)
#   Model B: well-calibrated but worse ranked (AUC=0.78)
# Show AUC and log-loss for both
# Which would you use for bidding? Why? (hint: bid = CTR * CVR * target_cpa)

# %%
# TODO: Compute and plot all three metrics on your best Criteo model from Day 2/3
# Plot: (1) ROC curve, (2) PR curve, (3) calibration plot

# %% [markdown]
# ## Reflection
# 1. A model has AUC=0.80 but calibration error of 3x (predicts 0.03 when true rate is 0.01). What breaks in the ads system?
# 2. Why is NE (Normalized Entropy) used at Facebook/Meta instead of raw log-loss?
# 3. When would you use PR-AUC instead of ROC-AUC?
