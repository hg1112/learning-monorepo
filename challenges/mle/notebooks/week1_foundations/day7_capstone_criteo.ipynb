# %% [markdown]
# # Day 7 — Week 1 Capstone: Criteo CTR Benchmark
# **Week 1 | May 27**
#
# ## No New Paper — Consolidation Day
# Review your notes from papers read this week. Write a 5-sentence summary of what you'd tell a new hire about ML fundamentals for ads.
#
# ## Criteo Dataset
# - [Download from Kaggle](https://www.kaggle.com/competitions/criteo-display-ad-challenge/data) (use `train.csv`, first 500k rows)
# - 13 numeric features (I1–I13), 26 categorical features (C1–C26), binary label
# - ~0.26% click rate — classic imbalance problem
#
# ## Today's Goal
# Build a benchmark notebook comparing all 3 models from this week. This becomes your baseline for Week 2 deep CTR models.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# TODO: Load and preprocess Criteo sample
# - Numeric: fill NaN with median, StandardScaler
# - Categorical: LabelEncoder (just for this baseline; Week 2 uses embeddings)
# - Split: 80% train, 20% val

# %%
# TODO: Train all 3 models on same data split
# 1. Logistic Regression (from Day 2, or sklearn for speed)
# 2. LightGBM (from Day 3)
# 3. 2-layer Neural Net (from Day 4)

# %%
# TODO: Comparison table
# Report: Val AUC, Val Log-Loss, Train time (seconds), Inference time per 1000 samples
# Which would you deploy at Pinterest? Justify in 3 sentences.

# %%
# TODO: Calibration comparison
# Plot reliability curves for all 3 models
# Which is best calibrated out-of-box?
# What would you do to the worst-calibrated one before deploying?

# %% [markdown]
# ## Week 1 Summary — Write From Memory
# Before looking at notes, answer:
# 1. What is MLE and how does it relate to cross-entropy loss?
# 2. How does gradient boosting work in 3 sentences?
# 3. What is backpropagation? What is the chain rule?
# 4. Why is calibration critical for ads bidding?
# 5. What is attention, and why is it used in feature interaction modeling?
