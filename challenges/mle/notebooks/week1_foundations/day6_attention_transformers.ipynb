# %% [markdown]
# # Day 6 — Attention Mechanism & Transformers
# **Week 1 | May 26**
#
# ## Paper of the Day
# 📄 [Attention Is All You Need — Vaswani et al. (2017)](https://arxiv.org/abs/1706.03762)
# Read sections 1, 3.1 (Scaled Dot-Product Attention), and 3.2 (Multi-Head Attention). Skip the translation results.
#
# ## Resources
# - [The Illustrated Transformer — Jay Alammar](https://jalammar.github.io/illustrated-transformer/)
# - [Attention explained visually — 3Blue1Brown](https://www.youtube.com/watch?v=eMlx5fFNoYc)
# - [DCN v2 (Cross Network for ads) — Wang et al. 2021](https://arxiv.org/abs/2008.13535) — preview of Week 2
#
# ## Today's Goal
# Implement scaled dot-product attention in PyTorch (~15 lines). Understand why attention is useful for modeling feature interactions in ads (Cross Networks use a similar idea).

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math

# TODO: Implement scaled dot-product attention
# Attention(Q, K, V) = softmax(QK^T / sqrt(d_k)) * V
def scaled_dot_product_attention(Q, K, V, mask=None):
    # Q, K, V: (batch, seq_len, d_k)
    pass

# %%
# TODO: Implement multi-head attention
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super().__init__()
        # TODO: W_q, W_k, W_v, W_o projections
        pass
    
    def forward(self, Q, K, V, mask=None):
        # Split into heads, apply attention, concatenate, project
        pass

# %%
# TODO: Connect to ads context
# In ads, 'sequence' = user's recent interaction history (clicks, saves, searches)
# Attention lets the model weight which past interactions matter for the current ad
# Create a toy example: 5 past interactions, 1 candidate ad, use attention to score relevance

# %% [markdown]
# ## Reflection
# 1. Why does scaling by sqrt(d_k) matter? (hint: dot products grow with dimension)
# 2. How is attention used in Pinterest's user interest modeling?
# 3. What's the compute cost of full self-attention? Why does this matter for real-time serving?
