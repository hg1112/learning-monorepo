# %% [markdown]
# # Day 1 — Probability & Maximum Likelihood Estimation
# **Week 1 | May 21**
#
# ## Paper of the Day
# 📄 [A Few Useful Things to Know About Machine Learning — Domingos (2012)](https://dl.acm.org/doi/10.1145/2347736.2347755)
# Focus on sections 3 (Features) and 5 (Overfitting). Short read, high signal.
#
# ## Resources
# - [Probability & Statistics for ML — Stanford CS229 Notes](https://cs229.stanford.edu/notes2022fall/cs229-prob.pdf)
# - [MLE intuition — StatQuest YouTube](https://www.youtube.com/watch?v=XepXtl9YKwc)
# - [Bayesian vs Frequentist — explainxkcd style](https://seeing-theory.brown.edu/)
#
# ## Today's Goal
# Build intuition for MLE by implementing it from scratch. Understand why cross-entropy loss = negative log-likelihood.

# %% [markdown]
# ## 1. Key Formulas to Internalize
# Write out (don't copy-paste) before coding:
# - P(A|B) = P(B|A)P(A) / P(B)
# - MLE: θ* = argmax Σ log P(xi | θ)
# - Cross-entropy loss = -Σ y log(ŷ) = negative log-likelihood for Bernoulli

# %%
import numpy as np
import matplotlib.pyplot as plt

# TODO: Implement MLE for a Bernoulli distribution
# Generate 1000 coin flips with true p=0.7
# Estimate p via MLE — what's the closed-form solution?

# %%
# TODO: Implement a Naive Bayes classifier from scratch
# Features: 2 binary features (e.g., user_is_mobile, ad_is_image)
# Label: click (1) or no-click (0)
# Train: estimate P(feature | class) via MLE
# Predict: apply Bayes rule
# Generate synthetic data yourself

# %%
# TODO: Show that cross-entropy loss == negative log-likelihood
# Hint: write out the log-likelihood for a Bernoulli model
# and show it equals -sum(y*log(p) + (1-y)*log(1-p))

# %% [markdown]
# ## Reflection
# Answer before closing:
# 1. Why does MLE overfit on small datasets?
# 2. What's the prior equivalent in MAP estimation?
# 3. How does this connect to CTR prediction?
