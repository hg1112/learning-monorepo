# %% [markdown]
# # Day 4 — Neural Networks & Backpropagation
# **Week 1 | May 24**
#
# ## Paper of the Day
# 📄 [Learning Representations by Back-propagating Errors — Rumelhart, Hinton & Williams (1986)](https://www.nature.com/articles/323533a0)
# The original backprop paper. Short (3 pages). Then read:
# 📄 [Deep Learning — LeCun, Bengio & Hinton (2015)](https://www.nature.com/articles/nature14539) — sections 1 & 2 only.
#
# ## Resources
# - [Andrej Karpathy: Yes you should understand backprop](https://karpathy.medium.com/yes-you-should-understand-backprop-e2f06eab496b)
# - [micrograd — Karpathy's tiny autograd engine (50 lines)](https://github.com/karpathy/micrograd)
# - [3Blue1Brown Neural Networks playlist](https://www.youtube.com/playlist?list=PLZHQObOWTQDNU6R1_67000Dx_ZCJB-3pi)
#
# ## Today's Goal
# Implement a 2-layer neural net with manual backprop. Verify gradients numerically. Understand why this matters for deep CTR models.

# %%
import numpy as np

# TODO: Implement 2-layer neural net (no PyTorch, pure numpy)
# Architecture: input -> Linear -> ReLU -> Linear -> Sigmoid -> output
# Forward pass: compute predictions
# Backward pass: compute dL/dW1, dL/db1, dL/dW2, dL/db2

class TwoLayerNet:
    def __init__(self, input_dim, hidden_dim, output_dim=1):
        # He initialization for ReLU
        pass
    
    def forward(self, X):
        # Cache intermediate values for backprop
        pass
    
    def backward(self, X, y_true):
        # Return dict of gradients
        pass
    
    def update(self, grads, lr=0.01):
        pass

# %%
# TODO: Numerical gradient check
# For each weight w: grad ≈ (loss(w+ε) - loss(w-ε)) / (2ε)
# Your analytical gradient should match to 1e-5 precision
# If they don't match, your backprop has a bug

# %%
# TODO: Train on Criteo sample (numeric features only)
# Compare: logistic regression vs 2-layer net vs LightGBM
# Plot training loss curves
# Why does the net need more data to beat LightGBM on tabular data?

# %% [markdown]
# ## Reflection
# 1. What is the vanishing gradient problem? Why does ReLU help vs sigmoid hidden activations?
# 2. Why do deep CTR models use embedding layers for categorical features instead of one-hot encoding?
# 3. What's the difference between batch, mini-batch, and stochastic gradient descent?
