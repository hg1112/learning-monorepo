# %% [markdown]
# # Day 2 — Logistic Regression From Scratch
# **Week 1 | May 22**
#
# ## Paper of the Day
# 📄 [Logistic Regression in Rare Events Data — King & Zeng (2001)](https://gking.harvard.edu/files/0s.pdf)
# CTR data is extremely imbalanced (0.1% click rate). This paper explains why vanilla LR underestimates rare event probabilities and how to correct it.
#
# ## Resources
# - [Stanford CS229 Lecture Notes — Supervised Learning](https://cs229.stanford.edu/notes2022fall/main_notes.pdf) (Section 1)
# - [Visual explanation of sigmoid + log-loss — Chris Olah](https://colah.github.io/posts/2015-09-Visual-Information/)
# - [Gradient descent derivation — 3Blue1Brown](https://www.youtube.com/watch?v=IHZwWFHWa-w)
#
# ## Today's Goal
# Implement logistic regression end-to-end in numpy — forward pass, loss, gradients, gradient descent. Train on Criteo sample.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# TODO: Implement sigmoid function
def sigmoid(z):
    pass

# TODO: Implement binary cross-entropy loss
def bce_loss(y_true, y_pred):
    pass

# TODO: Implement gradient of loss w.r.t. weights
# Hint: gradient = X.T @ (y_pred - y_true) / n
def compute_gradients(X, y_true, y_pred):
    pass

# %%
# TODO: Implement training loop
class LogisticRegression:
    def __init__(self, lr=0.01, n_epochs=100):
        pass
    
    def fit(self, X, y):
        # Initialize weights, run gradient descent
        pass
    
    def predict_proba(self, X):
        pass

# %%
# TODO: Load Criteo sample (use first 100k rows)
# df = pd.read_csv('path/to/criteo_sample.csv', nrows=100000)
# Use numeric columns only (I1-I13), fill NaN with median
# Train your LR model, report AUC and log-loss
# Compare with sklearn's LogisticRegression

# %% [markdown]
# ## Reflection
# 1. Why does gradient descent converge slowly on unscaled features?
# 2. What happens to predictions when class imbalance is ~0.1% clicks?
# 3. How would you adapt this for online learning (streaming data)?
