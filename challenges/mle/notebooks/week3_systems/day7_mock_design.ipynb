# %% [markdown]
# # Day 7 — Full Mock System Design
# **Week 3 | June 10**
#
# ## No New Paper — Practice Day
#
# ## Instructions
# 1. Close all notes
# 2. Set a 45-minute timer
# 3. Answer the question below out loud as if interviewing
# 4. Then open this notebook and fill in the gaps
#
# ## Interview Question
# > **"Design Pinterest's programmatic ads ranking system from scratch.
# > Pinterest wants to rank ads for a user browsing their home feed.
# > Walk me through your approach."**
#
# ## Scoring Rubric (use after your attempt)
# - [ ] Clarified requirements (scale, latency, business metric)
# - [ ] Named the offline path (training data, features, model)
# - [ ] Named the online path (retrieval, ranking, bid calc)
# - [ ] Addressed latency (<100ms)
# - [ ] Addressed calibration
# - [ ] Addressed experimentation (how to evaluate a new model)
# - [ ] Discussed failure modes and fallbacks
# - [ ] Staff-level: cross-team dependencies, rollout plan

# %%
# After your verbal attempt, fill in each section:

# == REQUIREMENTS ==
# Scale: ? QPS, ? advertisers, ? daily impressions
# Latency: ? ms
# North star metric: ?

# == OFFLINE PATH ==
# Training data: how collected, what's the label, how often retrained?
# Features: user features, ad features, context features
# Model: architecture choice + justification
# Evaluation: offline metrics

# == ONLINE PATH ==
# Retrieval: how do you get candidate ads? (not rank all 10M ads)
# Ranking: model inference
# Bid calculation: eCPM formula
# Pacing check: is budget remaining?

# == DEPLOYMENT ==
# How do you shadow-deploy a new model?
# What's your rollback criteria?
# Who are the stakeholders?

# %%
# TODO: Draw the architecture diagram as an ASCII diagram in a comment
# Force yourself to put boxes and arrows in text
# e.g.:
#
#  User Request
#      ↓
#  [Ad Server]
#      ↓
#  [Retrieval] ← [Ad Index]
#      ↓
#  [Ranking Model] ← [Feature Store]
#      ...

# %% [markdown]
# ## Post-Mock Review
# Compare your answers against your Week 3 notebooks.
# Write down the 2 things you missed and spend 30 min reviewing them.
